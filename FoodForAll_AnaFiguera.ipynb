# %% [markdown]
# <a href="https://colab.research.google.com/github/amavafi/DataScience/blob/main/FoodForAll_AnaFiguera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Primeros pasos 🤯
# :
# Son algunas de las pruebas necesarias para ir tomando el modelo de armado.

# %%
# !pip install pyGithub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.2/350.2 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 13.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# ...

# %%
import numpy as np
import pandas as pd
from github import Github

# %%
url = "https://raw.githubusercontent.com/amavafi/DataScience/main/DataSetProPo.csv"
df = pd.read_csv(url, sep = ',')
df
# Out:
#        M49 Code                             Country  Year  \
# 0            32                           Argentina  2000
# 1            32                           Argentina  2000
# 2            32                           Argentina  2000
# 3            32                           Argentina  2000
# 4            32                           Argentina  2000
# ...         ...                                 ...   ...
# 24003       862  Venezuela (Bolivarian Republic of)  2022
# 24004       862  Venezuela (Bolivarian Republic of)  2022
# 24005       862  Venezuela (Bolivarian Republic of)  2022
# 24006       862  Venezuela (Bolivarian Republic of)  2022
# 24007       862  Venezuela (Bolivarian Republic of)  2022
#
#                          Item Group  \
# 0                       Agriculture
# 1                       Agriculture
# 2      Vegetables and Fruit Primary
# 3                       Agriculture
# 4      Vegetables and Fruit Primary
# ...                             ...
# ...

# %% [markdown]
# Seguridad Alimentaria
# el desglose del data set apunta al analisis de la seguridad alimentaria y nutricion en las regiones de america y europa con el fin de diseñar politicas alimentarias y agricolas para contribuir en diestas saludables y asequibles.
# en ese sentido se plantean dos objetivos primarios:
# 1. End hunger, achieve food security and improved nutrition and promote sustainable agriculture
# 2. Ensure availability and sustainable management of water and sanitation for all
# Estos objetivos se encuentran en el marco de los objetivos de desarrollo sustentable SGD de la organización de alimentos y agricultura de las naciones unidad FAO

# %%
import pandas as pd
rawdata = '/Users/amavafi/Documents/Data Carreer/Data Science/230929_RawData.csv'
pd.read_csv(rawdata).head()
# Out:
#   Domain Code          Domain  Area Code (M49)           Area  Element Code  \
# 0        SDGB  SDG Indicators              248  Åland Islands          6173
# 1        SDGB  SDG Indicators              248  Åland Islands          6173
# 2        SDGB  SDG Indicators              248  Åland Islands          6173
# 3        SDGB  SDG Indicators              248  Åland Islands          6173
# 4        SDGB  SDG Indicators              248  Åland Islands          6173
#
#   Element   Item Code (SDG)                                        Item  \
# 0   Value  ER_RSK_LBREDS_NB  2.5.2 Number of local breeds (not extinct)
# 1   Value  ER_RSK_LBREDS_NB  2.5.2 Number of local breeds (not extinct)
# 2   Value  ER_RSK_LBREDS_NB  2.5.2 Number of local breeds (not extinct)
# 3   Value  ER_RSK_LBREDS_NB  2.5.2 Number of local breeds (not extinct)
# 4   Value  ER_RSK_LBREDS_NB  2.5.2 Number of local breeds (not extinct)
#
#    Year Code  Year Unit Value Flag Flag Description  \
# ...
